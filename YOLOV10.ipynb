# %%
# !git clone https://github.com/THU-MIG/yolov10.git
# Out:
# Cloning into 'yolov10'...

# %%
cd yolov10
# Out:
# C:\Users\NEEL\Downloads\major2\yolov10

# %%
# !pip install .
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Processing c:\users\neel\downloads\major2\yolov10
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for ultralytics: filename=ultralytics-8.1.34-py3-none-any.whl size=735414 sha256=dd798809c51197a8cf85af7c936cfcdcc5d90ba686d95e85b9057fa7299d6cf9
#   Stored in directory: C:\Users\NEEL\AppData\Local\Temp\pip-ephem-wheel-cache-yu8pfoqg\wheels\8f\cb\30\0646e490a4e94e3691725d6e8ad8e1666bedfcd726d24a9ad6
# Successfully built ultralytics
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.1.34
#     Uninstalling ultralytics-8.1.34:
# ...

# %%
import os
import urllib.request

# Create a directory for the weights in the current working directory
weights_dir = os.path.join(os.getcwd(), "weights")
os.makedirs(weights_dir, exist_ok=True)

# URLs of the weight files
urls = [
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10n.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10s.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10m.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10b.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10x.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10l.pt"
]

# Download each file
for url in urls:
    file_name = os.path.join(weights_dir, os.path.basename(url))
    urllib.request.urlretrieve(url, file_name)
    print(f"Downloaded {file_name}")
# Out:
# Downloaded C:\Users\NEEL\Downloads\major2\yolov10\weights\yolov10n.pt
# Downloaded C:\Users\NEEL\Downloads\major2\yolov10\weights\yolov10s.pt
# Downloaded C:\Users\NEEL\Downloads\major2\yolov10\weights\yolov10m.pt
# Downloaded C:\Users\NEEL\Downloads\major2\yolov10\weights\yolov10b.pt
# Downloaded C:\Users\NEEL\Downloads\major2\yolov10\weights\yolov10x.pt
# Downloaded C:\Users\NEEL\Downloads\major2\yolov10\weights\yolov10l.pt

# %%
import tensorflow as tf
from tensorflow import keras

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
tf.test.is_built_with_cuda()
print(tf.version.VERSION)
import sys
sys.version
# Out:
# C:\Users\NEEL\.conda\envs\gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:585: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   np.object,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import tensorflow as tf
#       2 from tensorflow import keras
#       3 print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
#
# File ~\.conda\envs\gpu\lib\site-packages\tensorflow\__init__.py:41
#      38 import six as _six
#      39 import sys as _sys
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      44 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# ...

# %%
# !yolo task=detect mode=train epochs=100 batch=16 plots=True model=C:/Users/NEEL/Downloads/yolov10/weights/yolov10n.pt data=C:/Users/NEEL/Downloads/traffic/data.yaml
# Out:
# ^C
# WARNING âš ï¸� Known issue with torch>=2.4.0 on Windows with CPU, recommend downgrading to torch<=2.3.1 to resolve https://github.com/ultralytics/ultralytics/issues/15049
# ...
# New https://pypi.org/project/ultralytics/8.2.102 available ðŸ˜ƒ Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.86 ðŸš€ Python-3.10.6 torch-2.4.1+cpu CPU (12th Gen Intel Core(TM) i5-12500H)
# ...

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model="C:\Users\NEEL\Downloads\PROJECTS\TA\model\weights\best.pt" source="C:\Users\NEEL\Downloads\PROJECTS\TA\IMAGES\13.png"
# Out:
# WARNING âš ï¸� Known issue with torch>=2.4.0 on Windows with CPU, recommend downgrading to torch<=2.3.1 to resolve https://github.com/ultralytics/ultralytics/issues/15049
# Ultralytics YOLOv8.2.86 ðŸš€ Python-3.10.6 torch-2.4.1+cpu CPU (12th Gen Intel Core(TM) i5-12500H)
# YOLOv10n summary (fused): 285 layers, 2,695,196 parameters, 0 gradients, 8.2 GFLOPs
#
# image 1/1 C:\Users\NEEL\Downloads\PROJECTS\TA\IMAGES\13.png: 320x640 (no detections), 129.7ms
# Speed: 1.0ms preprocess, 129.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# Results saved to runs\detect\predict6
# ðŸ’¡ Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model="C:\Users\NEEL\Downloads\PROJECTS\TA\model\weights\best.pt" source="C:\Users\NEEL\Downloads\PROJECTS\TA\3.mp4"
# Out:
# WARNING âš ï¸� Known issue with torch>=2.4.0 on Windows with CPU, recommend downgrading to torch<=2.3.1 to resolve https://github.com/ultralytics/ultralytics/issues/15049
# Ultralytics YOLOv8.2.86 ðŸš€ Python-3.10.6 torch-2.4.1+cpu CPU (12th Gen Intel Core(TM) i5-12500H)
# YOLOv10n summary (fused): 285 layers, 2,695,196 parameters, 0 gradients, 8.2 GFLOPs
#
# video 1/1 (frame 1/9888) C:\Users\NEEL\Downloads\PROJECTS\TA\3.mp4: 384x640 1 0, 109.1ms
# video 1/1 (frame 2/9888) C:\Users\NEEL\Downloads\PROJECTS\TA\3.mp4: 384x640 1 0, 99.6ms
# video 1/1 (frame 3/9888) C:\Users\NEEL\Downloads\PROJECTS\TA\3.mp4: 384x640 1 0, 78.1ms
# video 1/1 (frame 4/9888) C:\Users\NEEL\Downloads\PROJECTS\TA\3.mp4: 384x640 2 0s, 63.1ms
# video 1/1 (frame 5/9888) C:\Users\NEEL\Downloads\PROJECTS\TA\3.mp4: 384x640 1 0, 64.2ms
# video 1/1 (frame 6/9888) C:\Users\NEEL\Downloads\PROJECTS\TA\3.mp4: 384x640 2 0s, 110.2ms
# video 1/1 (frame 7/9888) C:\Users\NEEL\Downloads\PROJECTS\TA\3.mp4: 384x640 2 0s, 78.8ms
# ...
